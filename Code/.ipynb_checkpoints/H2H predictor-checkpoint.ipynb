# %% [markdown]
# David Hu
# Last updated: 12/28/2019

# %% [markdown]
# # EPL H2H match predictor

# %% [markdown]
# ## We examine the EPL H2H results from past 10 seasons (2018-2019 season in-progress)

# %%
# Import pandas and numpy
import pandas as pd
import numpy as np

# %%
# Read in the csv files as dataframes
season_0910 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-0910_csv.csv")
season_1011 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1011_csv.csv")
season_1112 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1112_csv.csv")
season_1213 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1213_csv.csv")
season_1314 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1314_csv.csv")
season_1415 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1415_csv.csv")
season_1516 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1516_csv.csv")
season_1617 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1617_csv.csv")
season_1718 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1718_csv.csv")


# 18-19 epl season still in-progress
season_1819 = pd.read_csv("C:/Users/huda9001/Documents/Coding/Soccer Analytics/Datasets/EPL H2H results/data/season-1819_csv.csv")

# %%
combined_results = pd.concat([season_0910,season_1011,season_1112,season_1213,season_1314,season_1415,season_1516,
                              season_1617,season_1718,season_1819])
combined_results.head()
# Out:
#          Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  2009-08-15  Aston Villa       Wigan     0     2   A     0     1   A
# 1  2009-08-15    Blackburn    Man City     0     2   A     0     1   A
# 2  2009-08-15       Bolton  Sunderland     0     1   A     0     1   A
# 3  2009-08-15      Chelsea        Hull     2     1   H     1     1   D
# 4  2009-08-15      Everton     Arsenal     1     6   A     0     3   A
#
#          Referee  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0  M Clattenburg  ...    5    7  15  14   4   6   2   2   0   0
# 1         M Dean  ...    9    5  12   9   5   4   2   1   0   0
# 2     A Marriner  ...    3   13  16  10   4   7   2   1   0   0
# 3        A Wiley  ...   12    3  13  15  12   4   1   2   0   0
# 4       M Halsey  ...    5    9  11  13   4   9   0   0   0   0
#
# [5 rows x 22 columns]

# %%
# Transform column names to more intuitive names
combined_results.columns = ['Date','Home Team','Away Team','FT Home Goals','FT Away Goals','FT Result',
                            'HT Home Goals','HT Away Goals','HT Result','Referee','Home Shots','Away Shots',
                            'Home SOT','Away SOT','Home Fouls','Away Fouls','Home Corners','Away Corners','Home YC',
                            'Away YC','Home RC','Away RC']
combined_results.head()
# Out:
#          Date    Home Team   Away Team  FT Home Goals  FT Away Goals  \
# 0  2009-08-15  Aston Villa       Wigan              0              2
# 1  2009-08-15    Blackburn    Man City              0              2
# 2  2009-08-15       Bolton  Sunderland              0              1
# 3  2009-08-15      Chelsea        Hull              2              1
# 4  2009-08-15      Everton     Arsenal              1              6
#
#   FT Result  HT Home Goals  HT Away Goals HT Result        Referee  ...  \
# 0         A              0              1         A  M Clattenburg  ...
# 1         A              0              1         A         M Dean  ...
# 2         A              0              1         A     A Marriner  ...
# 3         H              1              1         D        A Wiley  ...
# 4         A              0              3         A       M Halsey  ...
#
#    Home SOT  Away SOT  Home Fouls  Away Fouls  Home Corners  Away Corners  \
# ...

# %%
# Convert date to datetime
import datetime as dt
combined_results['Date'] = pd.to_datetime(combined_results['Date'])

# %%
# Summary statistics for matches
combined_results.describe()
# Out:
#        FT Home Goals  FT Away Goals  HT Home Goals  HT Away Goals  \
# count    3800.000000    3800.000000    3800.000000    3800.000000
# mean        1.570526       1.180000       0.691579       0.522368
# std         1.322363       1.160788       0.838739       0.735319
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       0.000000       0.000000
# 75%         2.000000       2.000000       1.000000       1.000000
# max         9.000000       7.000000       5.000000       5.000000
#
#         Home Shots   Away Shots     Home SOT     Away SOT   Home Fouls  \
# count  3800.000000  3800.000000  3800.000000  3800.000000  3800.000000
# mean     14.181316    11.229211     6.014211     4.763947    10.618684
# std       5.514299     4.687029     3.443571     2.891895     3.397368
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
# Looking at the frequency of home wins/away wins/draws
combined_results['FT Result'].value_counts()
# Out:
# H    1758
# A    1102
# D     940
# Name: FT Result, dtype: int64

# %%
print("Home win %:",1721/3719)
print("Away win %:",1072/3719)
print("Draw %:",926/3719)
# Out:
# Home win %: 0.46275880613068027
# Away win %: 0.28824952944339877
# Draw %: 0.24899166442592094

# %% [markdown]
# ## Looking at Manchester United to get a sense of season-over-season performance variability

# %%
# Selecting Manchester United results
man_united = combined_results.loc[(combined_results['Home Team'] == 'Man United') 
                     | (combined_results['Away Team'] == 'Man United')]
man_united
# Out:
#           Date       Home Team       Away Team  FT Home Goals  FT Away Goals  \
# 8   2009-08-16      Man United      Birmingham              1              0
# 13  2009-08-19         Burnley      Man United              1              0
# 21  2009-08-22           Wigan      Man United              0              5
# 29  2009-08-29      Man United         Arsenal              2              1
# 42  2009-09-12       Tottenham      Man United              1              3
# 54  2009-09-20      Man United        Man City              4              3
# 61  2009-09-26           Stoke      Man United              0              2
# 69  2009-10-03      Man United      Sunderland              2              2
# 79  2009-10-17      Man United          Bolton              2              1
# 93  2009-10-25       Liverpool      Man United              2              0
# 101 2009-10-31      Man United       Blackburn              2              0
# ...

# %%
# Season over season change for Manchester United
manu_0910 = man_united[(man_united['Date'] >= "2009-08-01") & (man_united['Date'] <= "2010-07-01")]
manu_1011 = man_united[(man_united['Date'] >= "2010-08-01") & (man_united['Date'] <= "2011-07-01")]
manu_1112 = man_united[(man_united['Date'] >= "2011-08-01") & (man_united['Date'] <= "2012-07-01")]
manu_1213 = man_united[(man_united['Date'] >= "2012-08-01") & (man_united['Date'] <= "2013-07-01")]
manu_1314 = man_united[(man_united['Date'] >= "2013-08-01") & (man_united['Date'] <= "2014-07-01")]
manu_1415 = man_united[(man_united['Date'] >= "2014-08-01") & (man_united['Date'] <= "2015-07-01")]
manu_1516 = man_united[(man_united['Date'] >= "2015-08-01") & (man_united['Date'] <= "2016-07-01")]
manu_1617 = man_united[(man_united['Date'] >= "2016-08-01") & (man_united['Date'] <= "2017-07-01")]
manu_1718 = man_united[(man_united['Date'] >= "2017-08-01") & (man_united['Date'] <= "2018-07-01")]
manu_1819 = man_united[(man_united['Date'] >= "2018-08-01") & (man_united['Date'] <= "2019-07-01")]

# %%
# Calculate Man United point totals for each season, based on the match result data

# 2009-2010 season
pts_0910 = 0

# Iterating a dataframe
for index, row in manu_0910.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_0910 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_0910 += 3 
    elif(row['FT Result'] == 'D'):
        pts_0910 += 1
    else:
        pts_0910 += 0
        
# 2010-2011 season
pts_1011 = 0

# Iterating a dataframe
for index, row in manu_1011.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1011 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1011 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1011 += 1
    else:
        pts_1011 += 0
        
# 2011-2012 season
pts_1112 = 0

# Iterating a dataframe
for index, row in manu_1112.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1112 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1112 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1112 += 1
    else:
        pts_1112 += 0        

# 2012-2013 season
pts_1213 = 0

# Iterating a dataframe
for index, row in manu_1213.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1213 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1213 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1213 += 1
    else:
        pts_1213 += 0
        
# 2013-2014 season
pts_1314 = 0

# Iterating a dataframe
for index, row in manu_1314.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1314 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1314 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1314 += 1
    else:
        pts_1314 += 0
        
# 2014-2015 season
pts_1415 = 0

# Iterating a dataframe
for index, row in manu_1415.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1415 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1415 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1415 += 1
    else:
        pts_1415 += 0
        
# 2015-2016 season
pts_1516 = 0

# Iterating a dataframe
for index, row in manu_1516.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1516 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1516 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1516 += 1
    else:
        pts_1516 += 0
        
# 2016-2017 season
pts_1617 = 0

# Iterating a dataframe
for index, row in manu_1617.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1617 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1617 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1617 += 1
    else:
        pts_1617 += 0
        
# 2017-2018 season
pts_1718 = 0

# Iterating a dataframe
for index, row in manu_1718.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1718 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1718 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1718 += 1
    else:
        pts_1718 += 0
        
# 2018-2019 season
pts_1819 = 0

# Iterating a dataframe
for index, row in manu_1819.iterrows():
    if(row['Home Team'] == 'Man United' and row['FT Result'] == 'H'):
        pts_1819 += 3
    elif(row['Away Team'] == 'Man United' and row['FT Result'] == 'A'):
        pts_1819 += 3 
    elif(row['FT Result'] == 'D'):
        pts_1819 += 1
    else:
        pts_1819 += 0
        
manu_pts = np.array([pts_0910,pts_1011,pts_1112,pts_1213,pts_1314,pts_1415,pts_1516,pts_1617,pts_1718,pts_1819])

print("Points:",manu_pts)
print("Season variation:",np.diff(manu_pts))
# Out:
# Points: [85 80 89 89 64 70 66 69 81 66]
# Season variation: [ -5   9   0 -25   6  -4   3  12 -15]

# %%
manu_1718
# Out:
#           Date       Home Team       Away Team  FT Home Goals  FT Away Goals  \
# 8   2017-08-13      Man United        West Ham              4              0
# 16  2017-08-19         Swansea      Man United              0              4
# 23  2017-08-26      Man United       Leicester              2              0
# 36  2017-09-09           Stoke      Man United              2              2
# 49  2017-09-17      Man United         Everton              4              0
# 54  2017-09-23     Southampton      Man United              0              1
# 63  2017-09-30      Man United  Crystal Palace              4              0
# 72  2017-10-14       Liverpool      Man United              0              0
# 82  2017-10-21    Huddersfield      Man United              2              1
# 94  2017-10-28      Man United       Tottenham              1              0
# 106 2017-11-05         Chelsea      Man United              1              0
# ...

# %%
manu_1819
# Out:
#           Date       Home Team       Away Team  FT Home Goals  FT Away Goals  \
# 0   2018-08-10      Man United       Leicester              2              1
# 16  2018-08-19        Brighton      Man United              3              2
# 29  2018-08-27      Man United       Tottenham              0              3
# 37  2018-09-02         Burnley      Man United              0              2
# 46  2018-09-15         Watford      Man United              1              2
# 57  2018-09-22      Man United          Wolves              1              1
# 66  2018-09-29        West Ham      Man United              3              1
# 74  2018-10-06      Man United       Newcastle              3              2
# 82  2018-10-20         Chelsea      Man United              2              2
# 98  2018-10-28      Man United         Everton              2              1
# 101 2018-11-03     Bournemouth      Man United              1              2
# ...

# %% [markdown]
# ## Observation: We need to look at stats that we know before matches. The current set of features are static: halftime or post-match results

# %% [markdown]
# ## 1. Static Model: to inform which stats might be more important, let's first take a look at logistic regression using the static features

# %%
# import LogisticRegressionCV function from sci-kit learn

from sklearn.linear_model import LogisticRegression

# %%
# Break data into features and target (outcome variable)

# X is features array, y is outcomes
X = combined_results.drop(columns=['Date','Home Team','Away Team','FT Result','HT Result','Referee',
                                  'FT Home Goals','FT Away Goals','HT Home Goals','HT Away Goals']) # drop non-numerical features
Y = combined_results[['FT Result']]
y = np.ravel(Y,order='C') # flatten the outcome variable

# %%
# Split the features and outcomes arrays into train and test data
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y)
print(Xtrain.shape, ytrain.shape)
print(Xtest.shape, ytest.shape)
# Out:
# (2850, 12) (2850,)
# (950, 12) (950,)

# %%
# Fit the model on training data
logfit = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial')
logfit.fit(Xtrain,ytrain)
y_model = logfit.predict(Xtest)
# Out:
# C:\Users\huda9001\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# Use confusion matrix to evaluate performance
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(ytest, y_model)
cnf_matrix
# Out:
# array([[159,   8, 106],
#        [ 80,   8, 142],
#        [ 56,   7, 384]], dtype=int64)

# %%
# Use accuracy score to see percent correct predictions

# Import accuracy_score to predict results
from sklearn.metrics import accuracy_score  
accuracy_score(ytest, y_model)
# Out:
# 0.58

# %% [markdown]
# ## ~53-58% prediction accuracy using static stats

# %% [markdown]
# ## To see if Home/Away bias is accounted for in model, we can compare the predicted results to the actual results and see if they line up
#
# ### Historical rates are as follows- Home: 46% / Away 29% / Draw 25%

# %%
total_matches = len(ytest)

# Actual results are in the ytest array. We examine breakdown of H/A/D
actual_home = np.count_nonzero(ytest == 'H') 
actual_away = np.count_nonzero(ytest == 'A')
actual_draw = np.count_nonzero(ytest == 'D')

print("Actual results:","Home:",actual_home/total_matches,"Away:",actual_away/total_matches,"Draw:",actual_draw/total_matches)

# Print new line
print() 

# Model results are in the y_model array. We examine breakdown of H/A/D
model_home = np.count_nonzero(y_model == 'H') 
model_away = np.count_nonzero(y_model == 'A')
model_draw = np.count_nonzero(y_model == 'D')

print("Model results:","Home:",model_home/total_matches,"Away:",model_away/total_matches,"Draw:",model_draw/total_matches)
# Out:
# Actual results: Home: 0.4705263157894737 Away: 0.2873684210526316 Draw: 0.24210526315789474
#
# Model results: Home: 0.6652631578947369 Away: 0.3105263157894737 Draw: 0.024210526315789474

# %% [markdown]
# ## Initial model overpredicts occurrence of Home victories and underpredicts occurrence of Draws. Away results seem to be in-line

# %% [markdown]
# ## Model coefficients to determine most important factors

# %%
# Classes and model coefficients
print(logfit.classes_)
print()
print(Xtrain.columns)
print()
print(logfit.coef_)
# Out:
# ['A' 'D' 'H']
#
# Index(['Home Shots', 'Away Shots', 'Home SOT', 'Away SOT', 'Home Fouls',
#        'Away Fouls', 'Home Corners', 'Away Corners', 'Home YC', 'Away YC',
#        'Home RC', 'Away RC'],
#       dtype='object')
#
# [[ 0.02224087  0.00375432 -0.17110134  0.18174174 -0.00485264 -0.01345475
#    0.02394697 -0.07117426  0.06369742 -0.04080535  0.6362961  -0.31906964]
#  [-0.00885497 -0.01151954 -0.01098422 -0.00813791 -0.0065277   0.00965989
#    0.0217071   0.01283957  0.05464704  0.05881143 -0.05861532 -0.05185037]
#  [-0.0133859   0.00776522  0.18208556 -0.17360382  0.01138034  0.00379486
#   -0.04565406  0.05833469 -0.11834446 -0.01800609 -0.57768078  0.37092001]]

# %% [markdown]
# ## Plotting regression coefficients: Scatterplots

# %%
import matplotlib.pyplot as plt

# x-axis labels will remain consistent across all outcomes
xlabels = Xtrain.columns

# %%
# First plotting Away result coefficients
away_coef = logfit.coef_[0]

plt.bar(xlabels,away_coef,align='center')
away_fig = plt.gcf()
away_fig.set_size_inches(18, 6)
plt.title('Away Result Factors',fontdict = {'fontsize' : 30})

# Adding data labels
for a,b in zip(xlabels,away_coef):
    plt.text(a,b, str(round(b,2)),va='center',ha='center')

# %% [markdown]
# ## Away Result analysis:
#
# ### Home Red Cards is the strongest predictor of an Away win. This is an expected result. Likewise, an increase in Away Red Cards decreases the Away team's likelihood to win.
#
# ### We see that Away shots on target and Home shots on target have an inverse relationship on Away win outcome. As do Home and Away Yellow Cards. These are both expected results as well.
#
# ### What is surprising is the positive relationship between Home Shots and Away win outcome (though weak), and the negative relationship between Away Corners and win outcome. I would expect the opposite to be true in both these cases. The 0.02 relationship for Home Shots is close to 0, so we will not investigate further.
#
# ### Possible explanations for the Away corner relationship: based on some Internet research (Washington Post) the goal percentage off a corner is roughly 3%. The flip side is that teams can get counterattacked on corner kicks, though it doesn't seem that this would outweigh the offensive edge.

# %%
# Looking at Draw result coefficients
draw_coef = logfit.coef_[1]

plt.bar(xlabels,draw_coef,align='center')
draw_fig = plt.gcf()
draw_fig.set_size_inches(18, 6)
plt.title('Draw Result Factors',fontdict = {'fontsize' : 30})

# Adding data labels
for a,b in zip(xlabels,draw_coef):
    plt.text(a,b, str(round(b,2)),va='center',ha='center')

# %% [markdown]
# ## Draw Result analysis:
#
# ### From the previous section, it appears that our model underpredicts Draw occurences. Looking into the coefficients can possibly explain this. In general, the predictors in our dataset do not appear to have strong effect, either positive or negative, on Draw outcomes.
#
# ### It appears that the disciplinary/conduct features (yellow cards, red cards) have some effect on a draw scenario. Specifically our model predicts a greater likelihood of Draw if either Home/Away team accumulates a yellow card. Perhaps players exercise more caution when playing with a Yellow card, which leads to Draw outcomes.
#
# ### Inversely, there is a lower likelihood of Draw if either team accumulates a Red card. This makes sense as the other team would have a definite advantage playing with an extra person.

# %%
# Looking at Home result coefficients
home_coef = logfit.coef_[2]

plt.bar(xlabels,home_coef,align='center')
home_fig = plt.gcf()
home_fig.set_size_inches(18, 6)
plt.title('Home Result Factors',fontdict = {'fontsize' : 30})

# Adding data labels
for a,b in zip(xlabels,home_coef):
    plt.text(a,b, str(round(b,2)),va='center',ha='center')

# %% [markdown]
# ## Home Result analysis:
#
# ### Similar to the Away outcome, red cards are the greatest predictor of a Home win. Home Yellow Cards also impact (decrease) the Home win likelihood. This is expected
#
# ### Shots on Target is a strong predictor (due to correlation with goals scored). This is an expected result.
#
# ### Our model produces an unexpected result on Corner kicks. Namely, Home Corners are associated with lower likelihood of Home win and Away Corners are associated with higher likelihood. We would expect the opposite to be true.

# %% [markdown]
# ## Part 1 conclusion: We conclude this section by highlighting the top findings from our analysis of the "static" model
#
# ### Model tends to overpredict Home wins and underpredict Draws. We will see if this is still the case after formulating our "dynamic" model
#
# ### Red Cards are the greatest predictor in our model of outcome. These are pretty rare events, however, so they are tougher to incorporate in the model. It's possible to look at a rolling average to assess which teams are "more likely" to accumulate red cards.
# #### There is also a possibility to bring in Referees as a variable here: assigning a "strictness score" based on disciplinary history may be helpful
#
# ### Shots on Target is another strong predictor of outcome. This is correlated with goals scored, which makes sense.
#
# ### Note we removed goals in this initial static model because they produce a trivial result. We can, however, include goals as a moving average in our dynamic model.

# %% [markdown]
# ## 2. Dynamic Model: transforming static stats to moving averages, in order to predict results beforehand

# %%
# Start with the original combined_results table and derive new features
print(combined_results.head())

print()

print(X.head())
# Out:
#         Date    Home Team   Away Team  FT Home Goals  FT Away Goals FT Result  \
# 0 2009-08-15  Aston Villa       Wigan              0              2         A
# 1 2009-08-15    Blackburn    Man City              0              2         A
# 2 2009-08-15       Bolton  Sunderland              0              1         A
# 3 2009-08-15      Chelsea        Hull              2              1         H
# 4 2009-08-15      Everton     Arsenal              1              6         A
#
#    HT Home Goals  HT Away Goals HT Result        Referee  ...  Home SOT  \
# 0              0              1         A  M Clattenburg  ...         5
# 1              0              1         A         M Dean  ...         9
# 2              0              1         A     A Marriner  ...         3
# 3              1              1         D        A Wiley  ...        12
# 4              0              3         A       M Halsey  ...         5
#
# ...

# %%
# Create a function that selects all results (home and away) by team

def get_results(team_name):
    return combined_results.loc[(combined_results['Home Team'] == team_name) | (combined_results['Away Team'] == team_name)]

get_results('Man United')
# Out:
#           Date       Home Team       Away Team  FT Home Goals  FT Away Goals  \
# 8   2009-08-16      Man United      Birmingham              1              0
# 13  2009-08-19         Burnley      Man United              1              0
# 21  2009-08-22           Wigan      Man United              0              5
# 29  2009-08-29      Man United         Arsenal              2              1
# 42  2009-09-12       Tottenham      Man United              1              3
# 54  2009-09-20      Man United        Man City              4              3
# 61  2009-09-26           Stoke      Man United              0              2
# 69  2009-10-03      Man United      Sunderland              2              2
# 79  2009-10-17      Man United          Bolton              2              1
# 93  2009-10-25       Liverpool      Man United              2              0
# 101 2009-10-31      Man United       Blackburn              2              0
# ...

# %%
# Using the get_results formula, generate moving averages

# For each row, use get_results for Home Team, get_results for Away team and create two new columns:
## 1. Home team past 5 games goals
## 2. Away team past 5 games goals

# %%
def recent_goals(team_name):
    '''This function calculates the average # of goals scored in the last 5 games, based on the input team'''
    
    recent_matches = get_results(team_name)
    
    recent_matches['Last 5 Goals'] = recent_matches['FT Home Goals'].rolling(5).mean()
    
    return recent_matches
    
recent_goals('Man United')
# Out:
# C:\Users\huda9001\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           Date       Home Team       Away Team  FT Home Goals  FT Away Goals  \
# 8   2009-08-16      Man United      Birmingham              1              0
# 13  2009-08-19         Burnley      Man United              1              0
# 21  2009-08-22           Wigan      Man United              0              5
# 29  2009-08-29      Man United         Arsenal              2              1
# 42  2009-09-12       Tottenham      Man United              1              3
# 54  2009-09-20      Man United        Man City              4              3
# ...
